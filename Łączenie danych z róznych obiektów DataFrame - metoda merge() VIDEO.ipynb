# %%
import pandas as pd
import numpy as np

# %%
cat1 = pd.read_csv('./course-files/northwind-mongo-master/categories_del_1.csv', usecols = ['CategoryID','CategoryName'])

# %%
cat2 = pd.read_csv('./course-files/northwind-mongo-master/categories_del_2.csv', usecols = ['CategoryID','CategoryName'])

# %%
cat1
# Out:
#    CategoryID    CategoryName
# 0           2      Condiments
# 1           3     Confections
# 2           4  Dairy Products
# 3           5  Grains/Cereals
# 4           6    Meat/Poultry
# 5           7         Produce
# 6           8         Seafood

# %%
cat2
# Out:
#    CategoryID    CategoryName
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           7         Produce
# 5           8         Seafood

# %%
cat1.merge(cat2)
# Out:
#    CategoryID    CategoryName
# 0           2      Condiments
# 1           3     Confections
# 2           4  Dairy Products
# 3           7         Produce
# 4           8         Seafood

# %%
cat1.merge(cat2, on='CategoryID', suffixes=['_1','_2'])
# Out:
#    CategoryID  CategoryName_1  CategoryName_2
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           7         Produce         Produce
# 4           8         Seafood         Seafood

# %%
cat1.merge(cat2, on = 'CategoryID', how = 'outer', suffixes=['_1','_2'])
# Out:
#    CategoryID  CategoryName_1  CategoryName_2
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           5  Grains/Cereals             NaN
# 4           6    Meat/Poultry             NaN
# 5           7         Produce         Produce
# 6           8         Seafood         Seafood
# 7           1             NaN       Beverages

# %%
len(cat1)
# Out:
# 7

# %%
cat1.merge(cat2, on = 'CategoryID', how = 'outer', suffixes=['_1','_2'], indicator = True)
# Out:
#    CategoryID  CategoryName_1  CategoryName_2      _merge
# 0           2      Condiments      Condiments        both
# 1           3     Confections     Confections        both
# 2           4  Dairy Products  Dairy Products        both
# 3           5  Grains/Cereals             NaN   left_only
# 4           6    Meat/Poultry             NaN   left_only
# 5           7         Produce         Produce        both
# 6           8         Seafood         Seafood        both
# 7           1             NaN       Beverages  right_only

# %%
cat_merg = cat1.merge(cat2, on = 'CategoryID', how = 'outer', suffixes=['_1','_2'], indicator = True)

# %%
filter = cat_merg['_merge'] == 'left_only'
cat_merg[filter]
# Out:
#    CategoryID  CategoryName_1 CategoryName_2     _merge
# 3           5  Grains/Cereals            NaN  left_only
# 4           6    Meat/Poultry            NaN  left_only

# %%
cat1.merge(cat2, on = 'CategoryID', how = 'right', suffixes=['_1','_2'],indicator = True)
# Out:
#    CategoryID  CategoryName_1  CategoryName_2      _merge
# 0           2      Condiments      Condiments        both
# 1           3     Confections     Confections        both
# 2           4  Dairy Products  Dairy Products        both
# 3           7         Produce         Produce        both
# 4           8         Seafood         Seafood        both
# 5           1             NaN       Beverages  right_only
