# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
frame = pd.read_csv("./course-files/Fortune_500_2017.csv")

# %%
frame.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
frame.set_index('Rank', inplace = True)

# %%
frame[99:105]
# Out:
#                             Title                    Website  Employees  \
# Rank
# 100         Capital One Financial  http://www.capitalone.com      47300
# 101      Twenty-First Century Fox        http://www.21cf.com      21500
# 102                          USAA        http://www.usaa.com      29943
# 103           World Fuel Services     http://www.wfscorp.com       5000
# 104   Philip Morris International         http://www.pmi.com      79500
# 105                         Deere   http://www.johndeere.com      56767
#
#                          Sector                                  Industry  \
# Rank
# 100                  Financials                          Commercial Banks
# 101                       Media                             Entertainment
# 102                  Financials  Insurance: Property and Casualty (Stock)
# 103                      Energy                                    Energy
# 104   Food, Beverages & Tobacco                                   Tobacco
# ...

# %%
frame.loc[100:105] [['Title','Employees']]
# Out:
#                             Title  Employees
# Rank
# 100         Capital One Financial      47300
# 101      Twenty-First Century Fox      21500
# 102                          USAA      29943
# 103           World Fuel Services       5000
# 104   Philip Morris International      79500
# 105                         Deere      56767

# %%
frame.reset_index()
# Out:
#      Rank               Title                           Website  Employees  \
# 0       1             Walmart            http://www.walmart.com    2300000
# 1       2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2       3               Apple              http://www.apple.com     116000
# 3       4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4       5            McKesson           http://www.mckesson.com      68000
# ..    ...                 ...                               ...        ...
# 495   496       Michaels Cos.           http://www.michaels.com      31000
# 496   497       Toll Brothers       http://www.tollbrothers.com       4200
# 497   498               Yahoo              http://www.yahoo.com       8500
# 498   499       Vistra Energy       http://www.vistraenergy.com       4431
# 499   500      ABM Industries                http://www.abm.com     110000
#
# ...

# %%
frame.set_index('Title',inplace = True)

# %%
frame.head()
# Out:
#                                              Website  Employees       Sector  \
# Title
# Walmart                       http://www.walmart.com    2300000    Retailing
# Berkshire Hathaway  http://www.berkshirehathaway.com     367700   Financials
# Apple                           http://www.apple.com     116000   Technology
# Exxon Mobil                http://www.exxonmobil.com      72700       Energy
# McKesson                     http://www.mckesson.com      68000  Wholesalers
#
#                                                     Industry  \
# Title
# Walmart                                General Merchandisers
# Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# Apple                            Computers, Office Equipment
# Exxon Mobil                               Petroleum Refining
# McKesson                            Wholesalers: Health Care
#
#                            Hqlocation                  Hqaddr         Hqcity  \
# Title
# ...

# %%
frame.sort_index(inplace = True)

# %%
frame.loc['X':'Y']
# Out:
#                                  Website  Employees          Sector  \
# Title
# XPO Logistics         http://www.xpo.com      87000  Transportation
# Xcel Energy    http://www.xcelenergy.com      11476          Energy
# Xerox               http://www.xerox.com     133600      Technology
#
#                                    Industry       Hqlocation  \
# Title
# XPO Logistics  Transportation and Logistics    Greenwich, CT
# Xcel Energy     Utilities: Gas and Electric  Minneapolis, MN
# Xerox                  Computer Peripherals      Norwalk, CT
#
#                           Hqaddr       Hqcity Hqstate  Hqzip         Hqtel  \
# Title
# XPO Logistics    5 American Lane    Greenwich      CT   6831  855-976-6951
# Xcel Energy    414 Nicollet Mall  Minneapolis      MN  55401  612-330-5500
# Xerox             45 Glover Ave.      Norwalk      CT   6850  203-968-3000
#
#                ...                                      Ceo-title  \
# Title          ...
# ...
