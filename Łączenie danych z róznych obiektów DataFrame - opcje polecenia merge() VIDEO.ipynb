# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv('./course-files/northwind-mongo-master/products.csv', usecols =['ProductID','ProductName','CategoryID','UnitPrice'])

# %%
categories = pd.read_csv('./course-files/northwind-mongo-master/categories1.csv', usecols =['CategoryID','CategoryName','Description'])

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products.merge(categories, on = 'CategoryID').head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice CategoryName  \
# 0          1                Chai           1       18.0    Beverages
# 1          2               Chang           1       19.0    Beverages
# 2         24  Guaraná Fantástica           1        4.5    Beverages
# 3         34       Sasquatch Ale           1       14.0    Beverages
# 4         35      Steeleye Stout           1       18.0    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
categories.rename({'CategoryID':'ID'}, axis = 'columns',inplace = True)

# %%
categories.head()
# Out:
#    ID    CategoryName              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(categories, left_on = 'CategoryID', right_on = 'ID').head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice  ID CategoryName  \
# 0          1                Chai           1       18.0   1    Beverages
# 1          2               Chang           1       19.0   1    Beverages
# 2         24  Guaraná Fantástica           1        4.5   1    Beverages
# 3         34       Sasquatch Ale           1       14.0   1    Beverages
# 4         35      Steeleye Stout           1       18.0   1    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
products.rename({'ProductName':'Name'}, axis ='columns', inplace = True)

# %%
categories.rename({'CategoryName': 'Name'}, axis ='columns', inplace = True)

# %%
products.head()
# Out:
#    ProductID                          Name  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(categories, left_on = 'CategoryID', right_on = 'ID', suffixes = ['_prod','_category']).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice  ID Name_category  \
# 0          1                Chai           1       18.0   1     Beverages
# 1          2               Chang           1       19.0   1     Beverages
# 2         24  Guaraná Fantástica           1        4.5   1     Beverages
# 3         34       Sasquatch Ale           1       14.0   1     Beverages
# 4         35      Steeleye Stout           1       18.0   1     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
products.merge(categories, left_on = 'CategoryID', right_on = 'ID', suffixes = ['_prod','_category'],
              sort = True).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice  ID Name_category  \
# 0          1                Chai           1       18.0   1     Beverages
# 1          2               Chang           1       19.0   1     Beverages
# 2         24  Guaraná Fantástica           1        4.5   1     Beverages
# 3         34       Sasquatch Ale           1       14.0   1     Beverages
# 4         35      Steeleye Stout           1       18.0   1     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
categories.set_index('ID', inplace = True)

# %%
products.merge(categories, left_on = 'CategoryID', right_on = 'ID', suffixes = ['_prod','_category'],
              sort = True).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice Name_category  \
# 0          1                Chai           1       18.0     Beverages
# 1          2               Chang           1       19.0     Beverages
# 2         24  Guaraná Fantástica           1        4.5     Beverages
# 3         34       Sasquatch Ale           1       14.0     Beverages
# 4         35      Steeleye Stout           1       18.0     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
products.merge(categories, left_on = 'CategoryID', right_index = True, suffixes = ['_prod','_category'],
              sort = True).head()
# Out:
#     ProductID           Name_prod  CategoryID  UnitPrice Name_category  \
# 0           1                Chai           1       18.0     Beverages
# 1           2               Chang           1       19.0     Beverages
# 23         24  Guaraná Fantástica           1        4.5     Beverages
# 33         34       Sasquatch Ale           1       14.0     Beverages
# 34         35      Steeleye Stout           1       18.0     Beverages
#
#     Description
# 0   Soft drinks
# 1   Soft drinks
# 23  Soft drinks
# 33  Soft drinks
# 34  Soft drinks
