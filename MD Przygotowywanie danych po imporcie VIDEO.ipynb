# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
frame = pd.read_csv("./course-files/PublicTransitExpenses.csv", low_memory = False)

# %%
frame.head()
# Out:
#   5 digit NTD ID 4 digit NTD ID                               Agency  \
# 0          30098           3098      Washington County Commissioners
# 1          30098           3098      Washington County Commissioners
# 2          60107           6107  Texoma Area Paratransit System, Inc
# 3              9           0T09            Kalispel Tribe of Indians
# 4              9           0T09            Kalispel Tribe of Indians
#
#       Reporter Type Subrecipient Type Organization Type  \
# 0  Reduced Reporter               NaN               NaN
# 1  Reduced Reporter               NaN               NaN
# 2     Full Reporter               NaN               NaN
# 3  Reduced Reporter               NaN             Tribe
# 4  Reduced Reporter               NaN             Tribe
#
#    2015 Total Mode Vehicles (VOMS) Mode Type of Service  Primary UZA Code  \
# 0                              NaN   DR              PT               NaN
# ...

# %%
frame.head()
# Out:
#   5 digit NTD ID 4 digit NTD ID                               Agency  \
# 0          30098           3098      Washington County Commissioners
# 1          30098           3098      Washington County Commissioners
# 2          60107           6107  Texoma Area Paratransit System, Inc
# 3              9           0T09            Kalispel Tribe of Indians
# 4              9           0T09            Kalispel Tribe of Indians
#
#       Reporter Type Subrecipient Type Organization Type  \
# 0  Reduced Reporter               NaN               NaN
# 1  Reduced Reporter               NaN               NaN
# 2     Full Reporter               NaN               NaN
# 3  Reduced Reporter               NaN             Tribe
# 4  Reduced Reporter               NaN             Tribe
#
#    2015 Total Mode Vehicles (VOMS) Mode Type of Service  Primary UZA Code  \
# 0                              NaN   DR              PT               NaN
# ...

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 39 columns):
# 5 digit NTD ID                                             17844 non-null object
# 4 digit NTD ID                                             17719 non-null object
# Agency                                                     17844 non-null object
# Reporter Type                                              17844 non-null object
# Subrecipient Type                                          3072 non-null object
# Organization Type                                          17759 non-null object
# 2015 Total Mode Vehicles (VOMS)                            17522 non-null float64
# Mode                                                       17844 non-null object
# Type of Service                                            17840 non-null object
# Primary UZA Code                                           17712 non-null float64
# ...

# %%
frame = pd.read_csv("./course-files/PublicTransitExpenses.csv", 
                    usecols = ['Agency','Reporter Type','Organization Type',
                              'Rail (Y/N)', 'Fixed Route (Y/N)',
                              'Service Costs','Tires and Tubes','Total Operating Expenses',
                              'Service Area Population'],
                    low_memory = False)

# %%
frame.head()
# Out:
#                                 Agency     Reporter Type Organization Type  \
# 0      Washington County Commissioners  Reduced Reporter               NaN
# 1      Washington County Commissioners  Reduced Reporter               NaN
# 2  Texoma Area Paratransit System, Inc     Full Reporter               NaN
# 3            Kalispel Tribe of Indians  Reduced Reporter             Tribe
# 4            Kalispel Tribe of Indians  Reduced Reporter             Tribe
#
#    Service Area Population Rail (Y/N) Fixed Route (Y/N) Service Costs  \
# 0                      NaN        NaN               NaN         $0.00
# 1                      NaN        NaN               NaN         $0.00
# 2                      NaN        NaN               NaN           NaN
# 3                      NaN          N                 N           NaN
# 4                      NaN          N                 Y           NaN
#
#   Tires and Tubes Total Operating Expenses
# 0           $0.00               $122524.00
# ...

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
# Agency                      17844 non-null object
# Reporter Type               17844 non-null object
# Organization Type           17759 non-null object
# Service Area Population     14418 non-null float64
# Rail (Y/N)                  17318 non-null object
# Fixed Route (Y/N)           17318 non-null object
# Service Costs               10262 non-null object
# Tires and Tubes             5615 non-null object
# Total Operating Expenses    17844 non-null object
# dtypes: float64(1), object(8)
# memory usage: 9.6 MB

# %%
frame["Reporter Type"].unique()
# Out:
# array(['Reduced Reporter', 'Full Reporter', 'Separate Service',
#        'Rural Reporter'], dtype=object)

# %%
frame['Reporter Type'].value_counts()
# Out:
# Full Reporter       13345
# Rural Reporter       3116
# Reduced Reporter     1313
# Separate Service       70
# Name: Reporter Type, dtype: int64

# %%
frame['Reporter Type'] = frame['Reporter Type'].astype('category')

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
# Agency                      17844 non-null object
# Reporter Type               17844 non-null category
# Organization Type           17759 non-null object
# Service Area Population     14418 non-null float64
# Rail (Y/N)                  17318 non-null object
# Fixed Route (Y/N)           17318 non-null object
# Service Costs               10262 non-null object
# Tires and Tubes             5615 non-null object
# Total Operating Expenses    17844 non-null object
# dtypes: category(1), float64(1), object(7)
# memory usage: 8.5 MB

# %%
frame['Agency'] = frame['Agency'].astype('category')
frame['Organization Type'] = frame['Organization Type'].astype('category')

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
# Agency                      17844 non-null category
# Reporter Type               17844 non-null category
# Organization Type           17759 non-null category
# Service Area Population     14418 non-null float64
# Rail (Y/N)                  17318 non-null object
# Fixed Route (Y/N)           17318 non-null object
# Service Costs               10262 non-null object
# Tires and Tubes             5615 non-null object
# Total Operating Expenses    17844 non-null object
# dtypes: category(3), float64(1), object(5)
# memory usage: 5.3 MB

# %%
frame['Service Area Population'].fillna(0, inplace = True)

# %%
frame['Service Area Population'] = frame['Service Area Population'].astype('int')

# %%
frame[frame['Service Area Population']>0].head()
# Out:
#                                  Agency     Reporter Type  \
# 71            Reno-Sparks Indian Colony  Reduced Reporter
# 92                    City of Pocatello  Reduced Reporter
# 93   Lee-Russell Council of Governments  Reduced Reporter
# 94    Aiken Area Council on Aging, Inc.  Reduced Reporter
# 101                    City of Lawrence     Full Reporter
#
#                                      Organization Type  \
# 71                                               Tribe
# 92   City, County or Local Government Unit or Depar...
# 93                   MPO, COG or Other Planning Agency
# 94                                Area Agency on Aging
# 101                              Consolidated Reporter
#
#      Service Area Population Rail (Y/N) Fixed Route (Y/N) Service Costs  \
# 71                      1127          N                 Y           NaN
# 92                     81730          N                 Y           NaN
# ...

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
# Agency                      17844 non-null category
# Reporter Type               17844 non-null category
# Organization Type           17759 non-null category
# Service Area Population     17844 non-null int32
# Rail (Y/N)                  17318 non-null object
# Fixed Route (Y/N)           17318 non-null object
# Service Costs               10262 non-null object
# Tires and Tubes             5615 non-null object
# Total Operating Expenses    17844 non-null object
# dtypes: category(3), int32(1), object(5)
# memory usage: 5.2 MB

# %%
frame['Rail (Y/N)'].replace(('Y','N'),(True, False), inplace = True)

# %%
frame['Fixed Route (Y/N)'].replace(('Y','N'),(True, False), inplace = True)

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
# Agency                      17844 non-null category
# Reporter Type               17844 non-null category
# Organization Type           17759 non-null category
# Service Area Population     17844 non-null int32
# Rail (Y/N)                  17318 non-null object
# Fixed Route (Y/N)           17318 non-null object
# Service Costs               10262 non-null object
# Tires and Tubes             5615 non-null object
# Total Operating Expenses    17844 non-null object
# dtypes: category(3), int32(1), object(5)
# memory usage: 4.3 MB
