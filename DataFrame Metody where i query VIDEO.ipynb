# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
frame = pd.read_csv("./course-files/mcdonalds.csv", usecols=['Item','Category','Serving Size','Calories','TotalFat'])

# %%
has400CalOrMore = frame['Calories'] >= 400

# %%
has400CalOrMore[:5]
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Calories, dtype: bool

# %%
frame.where(has400CalOrMore).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0        NaN                               NaN             NaN       NaN
# 1        NaN                               NaN             NaN       NaN
# 2        NaN                               NaN             NaN       NaN
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0       NaN
# 1       NaN
# 2       NaN
# 3      28.0
# 4      23.0

# %%
frame[has400CalOrMore]
# Out:
#                Category                                               Item  \
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 5             Breakfast                               Steak & Egg McMuffin
# 6             Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7             Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# ..                  ...                                                ...
# 254  Smoothies & Shakes                McFlurry with M&M’s Candies (Snack)
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  TotalFat
# ...

# %%
frame.where(has400CalOrMore).dropna(how='all').head()
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  TotalFat
# 3     450.0      28.0
# 4     400.0      23.0
# 5     430.0      23.0
# 6     460.0      26.0
# 7     520.0      30.0

# %%
frame.query('Category == "Desserts"').head()
# Out:
#      Category                   Item     Serving Size  Calories  TotalFat
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250      13.0
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160       8.0
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150       6.0
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45       1.5
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330       9.0

# %%
frame.query('Category in ["Desserts","Beverages"]')
# Out:
#       Category                               Item       Serving Size  \
# 103   Desserts                    Baked Apple Pie      2.7 oz (77 g)
# 104   Desserts              Chocolate Chip Cookie    1 cookie (33 g)
# 105   Desserts              Oatmeal Raisin Cookie    1 cookie (33 g)
# 106   Desserts                Kids Ice Cream Cone        1 oz (29 g)
# 107   Desserts                   Hot Fudge Sundae     6.3 oz (179 g)
# 108   Desserts                 Hot Caramel Sundae     6.4 oz (182 g)
# 109   Desserts                  Strawberry Sundae     6.3 oz (178 g)
# 110  Beverages          Coca-Cola Classic (Small)       16 fl oz cup
# 111  Beverages         Coca-Cola Classic (Medium)       21 fl oz cup
# 112  Beverages          Coca-Cola Classic (Large)       30 fl oz cup
# 113  Beverages          Coca-Cola Classic (Child)       12 fl oz cup
# 114  Beverages                  Diet Coke (Small)       16 fl oz cup
# 115  Beverages                 Diet Coke (Medium)       21 fl oz cup
# ...
