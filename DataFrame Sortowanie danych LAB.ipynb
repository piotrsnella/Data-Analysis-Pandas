# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
fuel = pd.read_csv("./course-files/fuel.csv", low_memory = False, usecols = ['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'],index_col ='Vehicle ID')

# %%
fuel.loc[27681, 'Combined MPG (FT1)']=np.NaN

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550        Regular                17.0

# %%
fuel.sort_values(by=['Make','Model'])
# Out:
#             Year        Make                            Model  \
# Vehicle ID
# 27550       1984  AM General                DJ Po Vehicle 2WD
# 28426       1984  AM General                DJ Po Vehicle 2WD
# 27549       1984  AM General                 FJ8c Post Office
# 28425       1984  AM General                 FJ8c Post Office
# 1032        1985  AM General              Post Office DJ5 2WD
# ...          ...         ...                              ...
# 26294       2009       smart                     fortwo coupe
# 29812       2010       smart                     fortwo coupe
# 30918       2011       smart                     fortwo coupe
# 31064       2011       smart  fortwo electric drive cabriolet
# 31065       2011       smart      fortwo electric drive coupe
#
#                                   Class    Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD      Regular                17.0
# ...

# %%
fuel.sort_values(by=['Combined MPG (FT1)'],ascending=False)
# Out:
#             Year         Make               Model             Class  \
# Vehicle ID
# 31673       2012   Mitsubishi              i-MiEV   Subcompact Cars
# 32278       2012         Ford      Focus Electric      Compact Cars
# 32276       2011          BMW            Active E   Subcompact Cars
# 30979       2011       Nissan                Leaf      Midsize Cars
# 30978       2008         MINI               MiniE  Minicompact Cars
# ...          ...          ...                 ...               ...
# 6413        1990  Lamborghini            Countach       Two Seaters
# 4141        1988  Lamborghini            Countach       Two Seaters
# 2914        1987  Lamborghini            Countach       Two Seaters
# 27681       1984   Alfa Romeo  Spider Veloce 2000       Two Seaters
# 32106       2012    Mitsubish                 NaN               NaN
#
#               Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 31673       Electricity               112.0
# ...

# %%
fuel.sort_values(by=['Make','Combined MPG (FT1)'], ascending = [True, False])
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 1032        1985  AM General  Post Office DJ5 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
# ...          ...         ...                  ...
# 26294       2009       smart         fortwo coupe
# 29811       2010       smart     fortwo cabriolet
# 29812       2010       smart         fortwo coupe
# 30917       2011       smart     fortwo cabriolet
# 30918       2011       smart         fortwo coupe
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0
# ...

# %%
fuel.sort_values(by='Combined MPG (FT1)', na_position = 'first')
# Out:
#             Year         Make               Model             Class  \
# Vehicle ID
# 27681       1984   Alfa Romeo  Spider Veloce 2000       Two Seaters
# 32106       2012    Mitsubish                 NaN               NaN
# 2914        1987  Lamborghini            Countach       Two Seaters
# 6413        1990  Lamborghini            Countach       Two Seaters
# 5267        1989  Lamborghini            Countach       Two Seaters
# ...          ...          ...                 ...               ...
# 30978       2008         MINI               MiniE  Minicompact Cars
# 30979       2011       Nissan                Leaf      Midsize Cars
# 32276       2011          BMW            Active E   Subcompact Cars
# 32278       2012         Ford      Focus Electric      Compact Cars
# 31673       2012   Mitsubishi              i-MiEV   Subcompact Cars
#
#               Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27681           Regular                 NaN
# ...

# %%
fuel.sort_index(by='Vehicle ID')
# Out:
# C:\Users\piotr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#             Year        Make                    Model  \
# Vehicle ID
# 1           1985  Alfa Romeo       Spider Veloce 2000
# 2           1985     Bertone                     X1/9
# 3           1985   Chevrolet                 Corvette
# 4           1985   Chevrolet                 Corvette
# 5           1985      Nissan                    300ZX
# ...          ...         ...                      ...
# 34762       2011     Lincoln  Navigator Limo. 2WD FFV
# 34763       2011        Jeep       Grand Cherokee 4WD
# 34764       2011         Kia             Sportage 4WD
# 34765       2011     Lincoln           MKT Hearse AWD
# 34766       2011      Nissan    Murano CrossCabriolet
#
#                                   Class        Fuel Type  Combined MPG (FT1)
# Vehicle ID
# ...
