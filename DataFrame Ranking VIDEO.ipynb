# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
frame = pd.read_csv("./course-files/mcdonalds.csv", usecols=['Item','Category','Serving Size','Calories','TotalFat'])

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame['Calories'].rank().head()
# Out:
# 0    115.0
# 1     82.5
# 2    146.0
# 3    178.5
# 4    156.0
# Name: Calories, dtype: float64

# %%
frame['CaloriesRank'] = frame['Calories'].rank()

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     115.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)      82.5
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     146.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     178.5
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     156.0
#
#    TotalFat  CaloriesRank
# 0      13.0         115.0
# 1       8.0          82.5
# 2      23.0         146.0
# 3      28.0         178.5
# 4      23.0         156.0

# %%
frame.sort_values(by = 'Calories').head(22)
# Out:
#            Category                                               Item  \
# 125       Beverages                             Diet Dr Pepper (Child)
# 138    Coffee & Tea                                  Iced Tea (Medium)
# 137    Coffee & Tea                                   Iced Tea (Small)
# 136       Beverages                                Dasani Water Bottle
# 145    Coffee & Tea                                     Coffee (Small)
# 147    Coffee & Tea                                     Coffee (Large)
# 124       Beverages                             Diet Dr Pepper (Large)
# 139    Coffee & Tea                                   Iced Tea (Large)
# 122       Beverages                             Diet Dr Pepper (Small)
# 123       Beverages                            Diet Dr Pepper (Medium)
# 117       Beverages                                  Diet Coke (Child)
# 116       Beverages                                  Diet Coke (Large)
# ...

# %%
frame['CaloriesRank'] = frame['Calories'].rank(ascending = False)

# %%
frame.sort_values(by='Calories', ascending = False).head(20)
# Out:
#                Category                                               Item  \
# 82       Chicken & Fish                       Chicken McNuggets (40 piece)
# 32            Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31            Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34            Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33            Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 81       Chicken & Fish                       Chicken McNuggets (20 piece)
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 249  Smoothies & Shakes                            Chocolate Shake (Large)
# 246  Smoothies & Shakes                           Strawberry Shake (Large)
# 251  Smoothies & Shakes                             Shamrock Shake (Large)
# 243  Smoothies & Shakes                              Vanilla Shake (Large)
# ...

# %%
frame.sort_values(by='Calories', ascending = False, inplace = True)

# %%
frame.head()
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
#
#        Serving Size  Calories  TotalFat  CaloriesRank
# 82  22.8 oz (646 g)     260.0     118.0           1.0
# 32  15.3 oz (434 g)     259.0      60.0           2.0
# 31  14.8 oz (420 g)     258.0      56.0           3.0
# 34  15.4 oz (437 g)     257.0      50.0           4.0
# 33  14.9 oz (423 g)     256.0      46.0           5.0

# %%
frame.nlargest(n=3, columns = 'Calories')
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  TotalFat  CaloriesRank
# 82  22.8 oz (646 g)     260.0     118.0           1.0
# 32  15.3 oz (434 g)     259.0      60.0           2.0
# 31  14.8 oz (420 g)     258.0      56.0           3.0

# %%
frame.nsmallest(3, columns = 'Calories')
# Out:
#          Category              Item  Serving Size  Calories  TotalFat  \
# 145  Coffee & Tea    Coffee (Small)  12 fl oz cup       8.5       0.0
# 140  Coffee & Tea  Iced Tea (Child)  12 fl oz cup       8.5       0.0
# 139  Coffee & Tea  Iced Tea (Large)  30 fl oz cup       8.5       0.0
#
#      CaloriesRank
# 145         252.5
# 140         252.5
# 139         252.5

# %%
frame.tail(3)
# Out:
#          Category                Item  Serving Size  Calories  TotalFat  \
# 115     Beverages  Diet Coke (Medium)  21 fl oz cup       8.5       0.0
# 114     Beverages   Diet Coke (Small)  16 fl oz cup       8.5       0.0
# 146  Coffee & Tea     Coffee (Medium)  16 fl oz cup       8.5       0.0
#
#      CaloriesRank
# 115         252.5
# 114         252.5
# 146         252.5
