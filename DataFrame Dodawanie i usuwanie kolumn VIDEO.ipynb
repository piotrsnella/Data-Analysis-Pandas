# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
frame = pd.read_csv('./course-files/mcdonalds.csv', usecols=['Item','Category','Calories','TotalFat','Sugars','Protein','Cholesterol'], index_col = 'Item', squeeze = True)

# %%
frame.head()
# Out:
#                                    Category  Calories  TotalFat  Cholesterol  \
# Item
# Egg McMuffin                      Breakfast       300      13.0          260
# Egg White Delight                 Breakfast       250       8.0           25
# Sausage McMuffin                  Breakfast       370      23.0           45
# Sausage McMuffin with Egg         Breakfast       450      28.0          285
# Sausage McMuffin with Egg Whites  Breakfast       400      23.0           50
#
#                                   Sugars  Protein
# Item
# Egg McMuffin                           3       17
# Egg White Delight                      3       18
# Sausage McMuffin                       2       14
# Sausage McMuffin with Egg              2       21
# Sausage McMuffin with Egg Whites       2       21

# %%
frame.TotalFat.head()
# Out:
# Item
# Egg McMuffin                        13.0
# Egg White Delight                    8.0
# Sausage McMuffin                    23.0
# Sausage McMuffin with Egg           28.0
# Sausage McMuffin with Egg Whites    23.0
# Name: TotalFat, dtype: float64

# %%
frame['TotalFat'].head()
# Out:
# Item
# Egg McMuffin                        13.0
# Egg White Delight                    8.0
# Sausage McMuffin                    23.0
# Sausage McMuffin with Egg           28.0
# Sausage McMuffin with Egg Whites    23.0
# Name: TotalFat, dtype: float64

# %%
frame['TotalFat0']= 0

# %%
frame.head()
# Out:
#                                    Category  Calories  TotalFat  Cholesterol  \
# Item
# Egg McMuffin                      Breakfast       300      13.0          260
# Egg White Delight                 Breakfast       250       8.0           25
# Sausage McMuffin                  Breakfast       370      23.0           45
# Sausage McMuffin with Egg         Breakfast       450      28.0          285
# Sausage McMuffin with Egg Whites  Breakfast       400      23.0           50
#
#                                   Sugars  Protein  TotalFat0
# Item
# Egg McMuffin                           3       17          0
# Egg White Delight                      3       18          0
# Sausage McMuffin                       2       14          0
# Sausage McMuffin with Egg              2       21          0
# Sausage McMuffin with Egg Whites       2       21          0

# %%
SugarAndaFat = frame.Sugars + frame.TotalFat

# %%
frame['SugarAndaFat'] = SugarAndaFat

# %%
frame.head()
# Out:
#                                    Category  Calories  TotalFat  Cholesterol  \
# Item
# Egg McMuffin                      Breakfast       300      13.0          260
# Egg White Delight                 Breakfast       250       8.0           25
# Sausage McMuffin                  Breakfast       370      23.0           45
# Sausage McMuffin with Egg         Breakfast       450      28.0          285
# Sausage McMuffin with Egg Whites  Breakfast       400      23.0           50
#
#                                   Sugars  Protein  TotalFat0  SugarAndaFat
# Item
# Egg McMuffin                           3       17          0          16.0
# Egg White Delight                      3       18          0          11.0
# Sausage McMuffin                       2       14          0          25.0
# Sausage McMuffin with Egg              2       21          0          30.0
# Sausage McMuffin with Egg Whites       2       21          0          25.0

# %%
frame["SugarAndProtein"] = frame.Sugars + frame.Protein
frame.head()
# Out:
#                                    Category  Calories  TotalFat  Cholesterol  \
# Item
# Egg McMuffin                      Breakfast       300      13.0          260
# Egg White Delight                 Breakfast       250       8.0           25
# Sausage McMuffin                  Breakfast       370      23.0           45
# Sausage McMuffin with Egg         Breakfast       450      28.0          285
# Sausage McMuffin with Egg Whites  Breakfast       400      23.0           50
#
#                                   Sugars  Protein  TotalFat0  SugarAndaFat  \
# Item
# Egg McMuffin                           3       17          0          16.0
# Egg White Delight                      3       18          0          11.0
# Sausage McMuffin                       2       14          0          25.0
# Sausage McMuffin with Egg              2       21          0          30.0
# Sausage McMuffin with Egg Whites       2       21          0          25.0
#
# ...

# %%
frame.insert(loc = 2, column = "SPF", value = frame.Sugars+frame.Protein+frame.TotalFat)

# %%
frame.head()
# Out:
#                                    Category  Calories   SPF  TotalFat  \
# Item
# Egg McMuffin                      Breakfast       300  33.0      13.0
# Egg White Delight                 Breakfast       250  29.0       8.0
# Sausage McMuffin                  Breakfast       370  39.0      23.0
# Sausage McMuffin with Egg         Breakfast       450  51.0      28.0
# Sausage McMuffin with Egg Whites  Breakfast       400  46.0      23.0
#
#                                   Cholesterol  Sugars  Protein  TotalFat0  \
# Item
# Egg McMuffin                              260       3       17          0
# Egg White Delight                          25       3       18          0
# Sausage McMuffin                           45       2       14          0
# Sausage McMuffin with Egg                 285       2       21          0
# Sausage McMuffin with Egg Whites           50       2       21          0
#
#                                   SugarAndaFat  SugarAndProtein
# Item
# ...

# %%
del frame["SugarAndProtein"]

# %%
frame.head()
# Out:
#                                    Category  Calories   SPF  TotalFat  \
# Item
# Egg McMuffin                      Breakfast       300  33.0      13.0
# Egg White Delight                 Breakfast       250  29.0       8.0
# Sausage McMuffin                  Breakfast       370  39.0      23.0
# Sausage McMuffin with Egg         Breakfast       450  51.0      28.0
# Sausage McMuffin with Egg Whites  Breakfast       400  46.0      23.0
#
#                                   Cholesterol  Sugars  Protein  TotalFat0  \
# Item
# Egg McMuffin                              260       3       17          0
# Egg White Delight                          25       3       18          0
# Sausage McMuffin                           45       2       14          0
# Sausage McMuffin with Egg                 285       2       21          0
# Sausage McMuffin with Egg Whites           50       2       21          0
#
#                                   SugarAndaFat
# Item
# ...

# %%
frame = frame.drop(columns =["SugarAndaFat"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-9982025b5062> in <module>
# ----> 1 frame = frame.drop(columns =["SugarAndaFat"])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
frame.head()
# Out:
#                                    Category  Calories   SPF  TotalFat  \
# Item
# Egg McMuffin                      Breakfast       300  33.0      13.0
# Egg White Delight                 Breakfast       250  29.0       8.0
# Sausage McMuffin                  Breakfast       370  39.0      23.0
# Sausage McMuffin with Egg         Breakfast       450  51.0      28.0
# Sausage McMuffin with Egg Whites  Breakfast       400  46.0      23.0
#
#                                   Cholesterol  Sugars  Protein  TotalFat0
# Item
# Egg McMuffin                              260       3       17          0
# Egg White Delight                          25       3       18          0
# Sausage McMuffin                           45       2       14          0
# Sausage McMuffin with Egg                 285       2       21          0
# Sausage McMuffin with Egg Whites           50       2       21          0

# %%
frame.drop(labels="SugarAndaFat", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-44ee67cf92f1> in <module>
# ----> 1 frame.drop(labels="SugarAndaFat", inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
frame.drop(columns=["SPF"], inplace = True)

# %%
frame.head()
# Out:
#                                    Category  Calories  TotalFat  Cholesterol  \
# Item
# Egg McMuffin                      Breakfast       300      13.0          260
# Egg White Delight                 Breakfast       250       8.0           25
# Sausage McMuffin                  Breakfast       370      23.0           45
# Sausage McMuffin with Egg         Breakfast       450      28.0          285
# Sausage McMuffin with Egg Whites  Breakfast       400      23.0           50
#
#                                   Sugars  Protein  TotalFat0
# Item
# Egg McMuffin                           3       17          0
# Egg White Delight                      3       18          0
# Sausage McMuffin                       2       14          0
# Sausage McMuffin with Egg              2       21          0
# Sausage McMuffin with Egg Whites       2       21          0
