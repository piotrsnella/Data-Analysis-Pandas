# %%
import pandas as pd
import numpy as np

# %%
suppliers = pd.read_csv('./course-files/northwind-mongo-master/suppliers.csv', usecols = ['SupplierID','CompanyName','Country'])

# %%
suppliers.head()
# Out:
#    SupplierID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
customers = pd.read_csv('./course-files/northwind-mongo-master/customers.csv', usecols = ['CustomerID','CompanyName','Country'])

# %%
customers.head()
# Out:
#   CustomerID                         CompanyName  Country
# 0      ALFKI                 Alfreds Futterkiste  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a   Mexico
# 3      AROUT                     Around the Horn       UK
# 4      BERGS                 Berglunds snabbk?¶p   Sweden

# %%
len(suppliers)
# Out:
# 29

# %%
len(customers)
# Out:
# 91

# %%
df_append = suppliers.append(customers, ignore_index = True)

# %%
len(df_append)
# Out:
# 120

# %%
df_append.head(40)
# Out:
#                                CompanyName      Country CustomerID  SupplierID
# 0                           Exotic Liquids           UK        NaN         1.0
# 1               New Orleans Cajun Delights          USA        NaN         2.0
# 2                Grandma Kelly's Homestead          USA        NaN         3.0
# 3                            Tokyo Traders        Japan        NaN         4.0
# 4       Cooperativa de Quesos 'Las Cabras'        Spain        NaN         5.0
# 5                                 Mayumi's        Japan        NaN         6.0
# 6                             Pavlova Ltd.    Australia        NaN         7.0
# 7                  Specialty Biscuits Ltd.           UK        NaN         8.0
# 8                         PB Knäckebröd AB       Sweden        NaN         9.0
# 9                Refrescos Americanas LTDA       Brazil        NaN        10.0
# 10             Heli Süßwaren GmbH & Co. KG      Germany        NaN        11.0
# ...

# %%
supplier2 = suppliers.copy()
customer2 = customers.copy()

# %%
supplier2.rename({'SuppliersID' : 'CustomerID'}, axis = 'columns',inplace = True)

# %%
supplier2.head()
# Out:
#    SupplierID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
supplier2.append(customers)
# Out:
#                            CompanyName  Country CustomerID  SupplierID
# 0                       Exotic Liquids       UK        NaN         1.0
# 1           New Orleans Cajun Delights      USA        NaN         2.0
# 2            Grandma Kelly's Homestead      USA        NaN         3.0
# 3                        Tokyo Traders    Japan        NaN         4.0
# 4   Cooperativa de Quesos 'Las Cabras'    Spain        NaN         5.0
# ..                                 ...      ...        ...         ...
# 86                      Wartian Herkku  Finland      WARTH         NaN
# 87              Wellington Importadora   Brazil      WELLI         NaN
# 88                White Clover Markets      USA      WHITC         NaN
# 89                         Wilman Kala  Finland      WILMK         NaN
# 90                      Wolski  Zajazd   Poland      WOLZA         NaN
#
# [120 rows x 4 columns]

# %%
df_concat = pd.concat(objs = [supplier2,customers], ignore_index = True)
# Out:
# C:\Users\piotr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
len(df_concat)
# Out:
# 120

# %%
df_concat.head(30)
# Out:
#                                CompanyName      Country CustomerID  SupplierID
# 0                           Exotic Liquids           UK        NaN         1.0
# 1               New Orleans Cajun Delights          USA        NaN         2.0
# 2                Grandma Kelly's Homestead          USA        NaN         3.0
# 3                            Tokyo Traders        Japan        NaN         4.0
# 4       Cooperativa de Quesos 'Las Cabras'        Spain        NaN         5.0
# 5                                 Mayumi's        Japan        NaN         6.0
# 6                             Pavlova Ltd.    Australia        NaN         7.0
# 7                  Specialty Biscuits Ltd.           UK        NaN         8.0
# 8                         PB Knäckebröd AB       Sweden        NaN         9.0
# 9                Refrescos Americanas LTDA       Brazil        NaN        10.0
# 10             Heli Süßwaren GmbH & Co. KG      Germany        NaN        11.0
# ...
