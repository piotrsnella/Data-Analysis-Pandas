# %%
import pandas as pd
import numpy as np

# %%
incidents = pd.read_csv('./course-files/Canadian Railway Crossing Incidents.csv')

# %%
incidents.head()
# Out:
#          Region         EventType  Public automated  Public passive  Private  \
# 0  Newfoundland         Accidents                 0               0        0
# 1  Newfoundland        Fatalities                 0               0        0
# 2  Newfoundland  Serious injuries                 0               0        0
# 3   Nova Scotia         Accidents                 1               0        0
# 4   Nova Scotia        Fatalities                 0               0        0
#
#    Farm
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
incidents.set_index("Region")
# Out:
#                               EventType  Public automated  Public passive  \
# Region
# Newfoundland                  Accidents                 0               0
# Newfoundland                 Fatalities                 0               0
# Newfoundland           Serious injuries                 0               0
# Nova Scotia                   Accidents                 1               0
# Nova Scotia                  Fatalities                 0               0
# Nova Scotia            Serious injuries                 0               0
# New Brunswick                 Accidents                 0               0
# New Brunswick                Fatalities                 0               0
# New Brunswick          Serious injuries                 0               0
# Quebec                        Accidents                 4               0
# Quebec                       Fatalities                 1               0
# Quebec                 Serious injuries                 0               0
# ...

# %%
incidents.set_index("EventType")
# Out:
#                                  Region  Public automated  Public passive  \
# EventType
# Accidents                  Newfoundland                 0               0
# Fatalities                 Newfoundland                 0               0
# Serious injuries           Newfoundland                 0               0
# Accidents                   Nova Scotia                 1               0
# Fatalities                  Nova Scotia                 0               0
# Serious injuries            Nova Scotia                 0               0
# Accidents                 New Brunswick                 0               0
# Fatalities                New Brunswick                 0               0
# Serious injuries          New Brunswick                 0               0
# Accidents                        Quebec                 4               0
# Fatalities                       Quebec                 1               0
# ...

# %%
incidents = pd.read_csv('./course-files/Canadian Railway Crossing Incidents.csv')

# %%
incidents.set_index(keys=['EventType','Region'], inplace = True)

# %%
incidents.head()
# Out:
#                                Public automated  Public passive  Private  Farm
# EventType        Region
# Accidents        Newfoundland                 0               0        0     0
# Fatalities       Newfoundland                 0               0        0     0
# Serious injuries Newfoundland                 0               0        0     0
# Accidents        Nova Scotia                  1               0        0     0
# Fatalities       Nova Scotia                  0               0        0     0

# %%
incidents.sort_index(inplace = True)

# %%
incidents.head(10)
# Out:
#                                  Public automated  Public passive  Private  \
# EventType Region
# Accidents Alberta                               3               7        2
#           British Columbia                      4               1        0
#           Manitoba                              1               3        0
#           New Brunswick                         0               0        0
#           Newfoundland                          0               0        0
#           Northwest Territories                 0               0        0
#           Nova Scotia                           1               0        0
#           Ontario                               7               0        2
#           Quebec                                4               0        1
#           Saskatchewan                          1               3        0
#
#                                  Farm
# EventType Region
# Accidents Alberta                   0
# ...

# %%
incidents.sort_index(ascending =[True,False], inplace = True)

# %%
incidents.head()
# Out:
#                                  Public automated  Public passive  Private  \
# EventType Region
# Accidents Saskatchewan                          1               3        0
#           Quebec                                4               0        1
#           Ontario                               7               0        2
#           Nova Scotia                           1               0        0
#           Northwest Territories                 0               0        0
#
#                                  Farm
# EventType Region
# Accidents Saskatchewan              0
#           Quebec                    0
#           Ontario                   0
#           Nova Scotia               0
#           Northwest Territories     0
